# %%
# necessary imports:
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
# settings for our self-organizing map

som_dimensions = (15,15)
som_rectangular_grid_radius = 2
training_set_size = 2000
num_epochs = 300
learning_rate = 0.05
mnist_size = 28 # dimensions of the image

# %%
# class definition of our self-organizing map, all operations will be done on an instance
class SOM():
    
    # init method acts as a constructor to our instance
    def __init__(self):
        # make a Kohonen layer and initialize all the neurons with random weights
        self.kohonen = np.random.rand(som_dimensions[0]*som_dimensions[1]*mnist_size**2)
        self.kohonen = np.reshape(self.kohonen, (som_dimensions[0], som_dimensions[1], mnist_size, mnist_size))
        print(self.kohonen.shape)
    
    # method to train our SOM
    def train(self, x_train):
        i = 1
        while i <= num_epochs:
            print('Training on epoch {}'.format(i), end='... ', flush=True)
            self._train_one_epoch(x_train)
            print('Epoch {} complete'.format(i), flush=True)
            i += 1            
        print('Training complete.', flush=True)
    
    def _train_one_epoch(self, x_train):
        point = [-1,-1]
        for vector in x_train:
            min_dist = np.Infinity
            for i in range(som_dimensions[0]):
                for j in range(som_dimensions[1]):
#                     dist = np.sqrt(np.sum((vector.reshape(-1, mnist_size) - self.kohonen[i][j]) ** 2))
                    dist = np.linalg.norm(vector.reshape(-1, mnist_size) - self.kohonen[i][j])
                    if dist < min_dist:
                        min_dist = dist
                        point = [i, j]
        
            self._update_weights(point, vector)
        
    def _update_weights(self, point, vector):
        
        def isValidPoint(point):
            if point[0] < 0 or point[0] >= som_dimensions[0]:
                return False
            elif point[1] < 0 or point[1] >= som_dimensions[1]:
                return False
            return True
        
        x_diff = -som_rectangular_grid_radius
        # change weights of all points in the neighborhood
        while x_diff <= som_rectangular_grid_radius:
            y_diff = -som_rectangular_grid_radius
            
            while y_diff <= som_rectangular_grid_radius:
                if isValidPoint([point[0]+x_diff, point[1]+y_diff]):
                    # update weights
                    delta = vector.reshape(-1, mnist_size) - self.kohonen[point[0]+x_diff][point[1]+y_diff]
                    self.kohonen[point[0]+x_diff][point[1]+y_diff] += learning_rate * delta
                y_diff += 1
            
            x_diff += 1

    def visualize(self):
        pass

# %%
# using tensorflow's default MNIST library
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data", one_hot=True)


x_train = mnist.train.images[:training_set_size,:]    
y_train = mnist.train.labels[:training_set_size,:]
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
# checking if the dataset loaded correctly
# for the MNIST dataset each element in the x_train array is a 28*28=784 size one-dimensional array
print(x_train.shape)
print(type(x_train[0][0]))
# Out:
# (2000, 784)
# <class 'numpy.float32'>

# %%
# creating an instance of our SOM class, this will be used to perform operations
train_SOM = SOM()
# training our SOM
train_SOM.train(x_train)
# Out:
# (15, 15, 28, 28)
# Training on epoch 1... Epoch 1 complete
# Training on epoch 2... Epoch 2 complete
# Training on epoch 3... Epoch 3 complete
# Training on epoch 4... Epoch 4 complete
# Training on epoch 5... Epoch 5 complete
# Training on epoch 6... Epoch 6 complete
# Training on epoch 7... Epoch 7 complete
# Training on epoch 8... Epoch 8 complete
# Training on epoch 9... Epoch 9 complete
# Training on epoch 10... Epoch 10 complete
# Training on epoch 11... Epoch 11 complete
# Training on epoch 12... Epoch 12 complete
# Training on epoch 13... Epoch 13 complete
# Training on epoch 14... Epoch 14 complete
# Training on epoch 15... Epoch 15 complete
# Training on epoch 16... Epoch 16 complete
# Training on epoch 17... Epoch 17 complete
# Training on epoch 18... Epoch 18 complete
# Training on epoch 19... Epoch 19 complete
# Training on epoch 20... Epoch 20 complete
# Training on epoch 21... Epoch 21 complete
# Training on epoch 22... Epoch 22 complete
# Training on epoch 23... Epoch 23 complete
# Training on epoch 24... Epoch 24 complete
# Training on epoch 25... Epoch 25 complete
# Training on epoch 26... Epoch 26 complete
# Training on epoch 27... Epoch 27 complete
# Training on epoch 28... Epoch 28 complete
# Training on epoch 29... Epoch 29 complete
# Training on epoch 30... Epoch 30 complete
# Training on epoch 31... Epoch 31 complete
# Training on epoch 32... Epoch 32 complete
# Training on epoch 33... Epoch 33 complete
# Training on epoch 34... Epoch 34 complete
# Training on epoch 35... Epoch 35 complete
# Training on epoch 36... Epoch 36 complete
# Training on epoch 37... Epoch 37 complete
# Training on epoch 38... Epoch 38 complete
# Training on epoch 39... Epoch 39 complete
# Training on epoch 40... Epoch 40 complete
# Training on epoch 41... Epoch 41 complete
# Training on epoch 42... Epoch 42 complete
# Training on epoch 43... Epoch 43 complete
# Training on epoch 44... Epoch 44 complete
# Training on epoch 45... Epoch 45 complete
# Training on epoch 46... Epoch 46 complete
# Training on epoch 47... Epoch 47 complete
# Training on epoch 48... Epoch 48 complete
# Training on epoch 49... Epoch 49 complete
# Training on epoch 50... Epoch 50 complete
# Training on epoch 51... Epoch 51 complete
# Training on epoch 52... Epoch 52 complete
# Training on epoch 53... Epoch 53 complete
# Training on epoch 54... Epoch 54 complete
# Training on epoch 55... Epoch 55 complete
# Training on epoch 56... Epoch 56 complete
# Training on epoch 57... Epoch 57 complete
# Training on epoch 58... Epoch 58 complete
# Training on epoch 59... Epoch 59 complete
# Training on epoch 60... Epoch 60 complete
# Training on epoch 61... Epoch 61 complete
# Training on epoch 62... Epoch 62 complete
# Training on epoch 63... Epoch 63 complete
# Training on epoch 64... Epoch 64 complete
# Training on epoch 65... Epoch 65 complete
# Training on epoch 66... Epoch 66 complete
# Training on epoch 67... Epoch 67 complete
# Training on epoch 68... Epoch 68 complete
# Training on epoch 69... Epoch 69 complete
# Training on epoch 70... Epoch 70 complete
# Training on epoch 71... Epoch 71 complete
# Training on epoch 72... Epoch 72 complete
# Training on epoch 73... Epoch 73 complete
# Training on epoch 74... Epoch 74 complete
# Training on epoch 75... Epoch 75 complete
# Training on epoch 76... Epoch 76 complete
# Training on epoch 77... Epoch 77 complete
# Training on epoch 78... Epoch 78 complete
# Training on epoch 79... Epoch 79 complete
# Training on epoch 80... Epoch 80 complete
# Training on epoch 81... Epoch 81 complete
# Training on epoch 82... Epoch 82 complete
# Training on epoch 83... Epoch 83 complete
# Training on epoch 84... Epoch 84 complete
# Training on epoch 85... Epoch 85 complete
# Training on epoch 86... Epoch 86 complete
# Training on epoch 87... Epoch 87 complete
# Training on epoch 88... Epoch 88 complete
# Training on epoch 89... Epoch 89 complete
# Training on epoch 90... Epoch 90 complete
# Training on epoch 91... Epoch 91 complete
# Training on epoch 92... Epoch 92 complete
# Training on epoch 93... Epoch 93 complete
# Training on epoch 94... Epoch 94 complete
# Training on epoch 95... Epoch 95 complete
# Training on epoch 96... Epoch 96 complete
# Training on epoch 97... Epoch 97 complete
# Training on epoch 98... Epoch 98 complete
# Training on epoch 99... Epoch 99 complete
# Training on epoch 100... Epoch 100 complete
# Training on epoch 101... Epoch 101 complete
# Training on epoch 102... Epoch 102 complete
# Training on epoch 103... Epoch 103 complete
# Training on epoch 104... Epoch 104 complete
# Training on epoch 105... Epoch 105 complete
# Training on epoch 106... Epoch 106 complete
# Training on epoch 107... Epoch 107 complete
# Training on epoch 108... Epoch 108 complete
# Training on epoch 109... Epoch 109 complete
# Training on epoch 110... Epoch 110 complete
# Training on epoch 111... Epoch 111 complete
# Training on epoch 112... Epoch 112 complete
# Training on epoch 113... Epoch 113 complete
# Training on epoch 114... Epoch 114 complete
# Training on epoch 115... Epoch 115 complete
# Training on epoch 116... Epoch 116 complete
# Training on epoch 117... Epoch 117 complete
# Training on epoch 118... Epoch 118 complete
# Training on epoch 119... Epoch 119 complete
# Training on epoch 120... Epoch 120 complete
# Training on epoch 121... Epoch 121 complete
# Training on epoch 122... Epoch 122 complete
# Training on epoch 123... Epoch 123 complete
# Training on epoch 124... Epoch 124 complete
# Training on epoch 125... Epoch 125 complete
# Training on epoch 126... Epoch 126 complete
# Training on epoch 127... Epoch 127 complete
# Training on epoch 128... Epoch 128 complete
# Training on epoch 129... Epoch 129 complete
# Training on epoch 130... Epoch 130 complete
# Training on epoch 131... Epoch 131 complete
# Training on epoch 132... Epoch 132 complete
# Training on epoch 133... Epoch 133 complete
# Training on epoch 134... Epoch 134 complete
# Training on epoch 135... Epoch 135 complete
# Training on epoch 136... Epoch 136 complete
# Training on epoch 137... Epoch 137 complete
# Training on epoch 138... Epoch 138 complete
# Training on epoch 139... Epoch 139 complete
# Training on epoch 140... Epoch 140 complete
# Training on epoch 141... Epoch 141 complete
# Training on epoch 142... Epoch 142 complete
# Training on epoch 143... Epoch 143 complete
# Training on epoch 144... Epoch 144 complete
# Training on epoch 145... Epoch 145 complete
# Training on epoch 146... Epoch 146 complete
# Training on epoch 147... Epoch 147 complete
# Training on epoch 148... Epoch 148 complete
# Training on epoch 149... Epoch 149 complete
# Training on epoch 150... Epoch 150 complete
# Training on epoch 151... Epoch 151 complete
# Training on epoch 152... Epoch 152 complete
# Training on epoch 153... Epoch 153 complete
# Training on epoch 154... Epoch 154 complete
# Training on epoch 155... Epoch 155 complete
# Training on epoch 156... Epoch 156 complete
# Training on epoch 157... Epoch 157 complete
# Training on epoch 158... Epoch 158 complete
# Training on epoch 159... Epoch 159 complete
# Training on epoch 160... Epoch 160 complete
# Training on epoch 161... Epoch 161 complete
# Training on epoch 162... Epoch 162 complete
# Training on epoch 163... Epoch 163 complete
# Training on epoch 164... Epoch 164 complete
# Training on epoch 165... Epoch 165 complete
# Training on epoch 166... Epoch 166 complete
# Training on epoch 167... Epoch 167 complete
# Training on epoch 168... Epoch 168 complete
# Training on epoch 169... Epoch 169 complete
# Training on epoch 170... Epoch 170 complete
# Training on epoch 171... Epoch 171 complete
# Training on epoch 172... Epoch 172 complete
# Training on epoch 173... Epoch 173 complete
# Training on epoch 174... Epoch 174 complete
# Training on epoch 175... Epoch 175 complete
# Training on epoch 176... Epoch 176 complete
# Training on epoch 177... Epoch 177 complete
# Training on epoch 178... Epoch 178 complete
# Training on epoch 179... Epoch 179 complete
# Training on epoch 180... Epoch 180 complete
# Training on epoch 181... Epoch 181 complete
# Training on epoch 182... Epoch 182 complete
# Training on epoch 183... Epoch 183 complete
# Training on epoch 184... Epoch 184 complete
# Training on epoch 185... Epoch 185 complete
# Training on epoch 186... Epoch 186 complete
# Training on epoch 187... Epoch 187 complete
# Training on epoch 188... Epoch 188 complete
# Training on epoch 189... Epoch 189 complete
# Training on epoch 190... Epoch 190 complete
# Training on epoch 191... Epoch 191 complete
# Training on epoch 192... Epoch 192 complete
# Training on epoch 193... Epoch 193 complete
# Training on epoch 194... Epoch 194 complete
# Training on epoch 195... Epoch 195 complete
# Training on epoch 196... Epoch 196 complete
# Training on epoch 197... Epoch 197 complete
# Training on epoch 198... Epoch 198 complete
# Training on epoch 199... Epoch 199 complete
# Training on epoch 200... Epoch 200 complete
# Training on epoch 201... Epoch 201 complete
# Training on epoch 202... Epoch 202 complete
# Training on epoch 203... Epoch 203 complete
# Training on epoch 204... Epoch 204 complete
# Training on epoch 205... Epoch 205 complete
# Training on epoch 206... Epoch 206 complete
# Training on epoch 207... Epoch 207 complete
# Training on epoch 208...

# %%
# visualizing results using matplotlib:
fig, axs = plt.subplots(nrows=som_dimensions[0], ncols=som_dimensions[1])
plt.axis('off')
plt.xticks(color='w')
plt.yticks(color='w')
plt.figure(figsize=(50,50))

# for i in range(som_dimensions[0]):
#     for j in range(som_dimensions[1]):
#         axs[i, j].imshow(train_SOM.kohonen[i][j], aspect='auto', cmap='gray')

i=0
for row in axs:
    j=0
    for col in row:
        col.imshow(train_SOM.kohonen[i][j], aspect = 'auto', cmap='gray')
        j += 1
    i += 1
        
plt.show()
